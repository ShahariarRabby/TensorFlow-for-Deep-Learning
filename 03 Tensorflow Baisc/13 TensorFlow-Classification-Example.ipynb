# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\shaha\AppData\Local\Temp\tmpdqwnhj4j
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\shaha\\AppData\\Local\\Temp\\tmpdqwnhj4j', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000014929B12240>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\shaha\AppData\Local\Temp\tmpdqwnhj4j\model.ckpt.
# INFO:tensorflow:loss = 6.93147, step = 1
# INFO:tensorflow:global_step/sec: 76.8957
# INFO:tensorflow:loss = 5.94172, step = 101 (1.302 sec)
# INFO:tensorflow:global_step/sec: 90.6043
# INFO:tensorflow:loss = 4.54054, step = 201 (1.104 sec)
# INFO:tensorflow:global_step/sec: 89.0116
# INFO:tensorflow:loss = 5.85977, step = 301 (1.126 sec)
# INFO:tensorflow:global_step/sec: 86.647
# INFO:tensorflow:loss = 4.63007, step = 401 (1.152 sec)
# INFO:tensorflow:global_step/sec: 87.6798
# INFO:tensorflow:loss = 3.86119, step = 501 (1.143 sec)
# INFO:tensorflow:global_step/sec: 87.3247
# INFO:tensorflow:loss = 5.09692, step = 601 (1.143 sec)
# INFO:tensorflow:global_step/sec: 84.0359
# INFO:tensorflow:loss = 5.31576, step = 701 (1.191 sec)
# INFO:tensorflow:global_step/sec: 74.3758
# INFO:tensorflow:loss = 5.81619, step = 801 (1.351 sec)
# INFO:tensorflow:global_step/sec: 75.1888
# INFO:tensorflow:loss = 4.44065, step = 901 (1.323 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\shaha\AppData\Local\Temp\tmpdqwnhj4j\model.ckpt.
# INFO:tensorflow:Loss for final step: 6.57255.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-27-15:11:08
# INFO:tensorflow:Restoring parameters from C:\Users\shaha\AppData\Local\Temp\tmpdqwnhj4j\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-11-27-15:11:09
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.724409, accuracy_baseline = 0.65748, auc = 0.782504, auc_precision_recall = 0.61916, average_loss = 0.535041, global_step = 1000, label/mean = 0.34252, loss = 5.22694, prediction/mean = 0.36748

# %%
results
# Out:
# {'accuracy': 0.72440946,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.78250402,
#  'auc_precision_recall': 0.61916029,
#  'average_loss': 0.53504092,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.2269382,
#  'prediction/mean': 0.3674804}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\shaha\AppData\Local\Temp\tmpdqwnhj4j\model.ckpt-1000
# [{'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53769606], dtype=float32),
#   'logits': array([ 0.15107083], dtype=float32),
#   'probabilities': array([ 0.462304  ,  0.53769606], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62043554], dtype=float32),
#   'logits': array([ 0.49139726], dtype=float32),
#   'probabilities': array([ 0.37956446,  0.62043554], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38693812], dtype=float32),
#   'logits': array([-0.46020114], dtype=float32),
#   'probabilities': array([ 0.6130619 ,  0.38693812], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32744095], dtype=float32),
#   'logits': array([-0.71978223], dtype=float32),
#   'probabilities': array([ 0.67255908,  0.32744095], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14501421], dtype=float32),
#   'logits': array([-1.77425313], dtype=float32),
#   'probabilities': array([ 0.85498583,  0.14501421], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6664632], dtype=float32),
#   'logits': array([ 0.69223166], dtype=float32),
#   'probabilities': array([ 0.33353683,  0.6664632 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.58796591], dtype=float32),
#   'logits': array([ 0.35556281], dtype=float32),
#   'probabilities': array([ 0.41203412,  0.58796591], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3525798], dtype=float32),
#   'logits': array([-0.60771865], dtype=float32),
#   'probabilities': array([ 0.64742023,  0.35257977], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23810236], dtype=float32),
#   'logits': array([-1.16311157], dtype=float32),
#   'probabilities': array([ 0.76189762,  0.23810236], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24655651], dtype=float32),
#   'logits': array([-1.11706281], dtype=float32),
#   'probabilities': array([ 0.75344354,  0.24655652], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12326863], dtype=float32),
#   'logits': array([-1.96183467], dtype=float32),
#   'probabilities': array([ 0.8767314 ,  0.12326864], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15265948], dtype=float32),
#   'logits': array([-1.71389294], dtype=float32),
#   'probabilities': array([ 0.84734058,  0.15265948], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30638924], dtype=float32),
#   'logits': array([-0.81705457], dtype=float32),
#   'probabilities': array([ 0.69361073,  0.30638924], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57365435], dtype=float32),
#   'logits': array([ 0.29677653], dtype=float32),
#   'probabilities': array([ 0.42634571,  0.57365435], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16504456], dtype=float32),
#   'logits': array([-1.62116289], dtype=float32),
#   'probabilities': array([ 0.83495545,  0.16504456], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32671601], dtype=float32),
#   'logits': array([-0.72307587], dtype=float32),
#   'probabilities': array([ 0.67328399,  0.32671601], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37006837], dtype=float32),
#   'logits': array([-0.53192353], dtype=float32),
#   'probabilities': array([ 0.62993163,  0.37006837], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12289798], dtype=float32),
#   'logits': array([-1.96526873], dtype=float32),
#   'probabilities': array([ 0.87710202,  0.12289798], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37468174], dtype=float32),
#   'logits': array([-0.51218373], dtype=float32),
#   'probabilities': array([ 0.62531823,  0.37468174], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14078021], dtype=float32),
#   'logits': array([-1.8088249], dtype=float32),
#   'probabilities': array([ 0.85921985,  0.14078021], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21445446], dtype=float32),
#   'logits': array([-1.29828107], dtype=float32),
#   'probabilities': array([ 0.78554553,  0.21445444], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29469308], dtype=float32),
#   'logits': array([-0.87269872], dtype=float32),
#   'probabilities': array([ 0.70530695,  0.29469305], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.66315514], dtype=float32),
#   'logits': array([ 0.6773864], dtype=float32),
#   'probabilities': array([ 0.33684486,  0.66315514], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21225958], dtype=float32),
#   'logits': array([-1.31135869], dtype=float32),
#   'probabilities': array([ 0.78774041,  0.21225958], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17829029], dtype=float32),
#   'logits': array([-1.52797413], dtype=float32),
#   'probabilities': array([ 0.82170975,  0.17829031], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.77558208], dtype=float32),
#   'logits': array([ 1.24010384], dtype=float32),
#   'probabilities': array([ 0.22441791,  0.77558208], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1802088], dtype=float32),
#   'logits': array([-1.51493347], dtype=float32),
#   'probabilities': array([ 0.8197912,  0.1802088], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29400218], dtype=float32),
#   'logits': array([-0.87602496], dtype=float32),
#   'probabilities': array([ 0.70599782,  0.29400218], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.09852959], dtype=float32),
#   'logits': array([-2.21367025], dtype=float32),
#   'probabilities': array([ 0.90147042,  0.0985296 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.58576143], dtype=float32),
#   'logits': array([ 0.34647048], dtype=float32),
#   'probabilities': array([ 0.41423857,  0.58576143], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.94334304], dtype=float32),
#   'logits': array([ 2.81241465], dtype=float32),
#   'probabilities': array([ 0.05665699,  0.94334304], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41845822], dtype=float32),
#   'logits': array([-0.32910573], dtype=float32),
#   'probabilities': array([ 0.58154178,  0.41845822], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.31544885], dtype=float32),
#   'logits': array([-0.77476674], dtype=float32),
#   'probabilities': array([ 0.68455112,  0.31544885], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5546605], dtype=float32),
#   'logits': array([ 0.21951938], dtype=float32),
#   'probabilities': array([ 0.44533947,  0.5546605 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24433924], dtype=float32),
#   'logits': array([-1.12903488], dtype=float32),
#   'probabilities': array([ 0.75566071,  0.24433926], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38622883], dtype=float32),
#   'logits': array([-0.46319222], dtype=float32),
#   'probabilities': array([ 0.6137712,  0.3862288], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5155229], dtype=float32),
#   'logits': array([ 0.06211162], dtype=float32),
#   'probabilities': array([ 0.48447707,  0.5155229 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62371659], dtype=float32),
#   'logits': array([ 0.50535333], dtype=float32),
#   'probabilities': array([ 0.37628344,  0.62371659], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.74470371], dtype=float32),
#   'logits': array([ 1.07056153], dtype=float32),
#   'probabilities': array([ 0.25529629,  0.74470365], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34379536], dtype=float32),
#   'logits': array([-0.6464262], dtype=float32),
#   'probabilities': array([ 0.65620464,  0.34379533], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18046071], dtype=float32),
#   'logits': array([-1.51322925], dtype=float32),
#   'probabilities': array([ 0.81953925,  0.18046071], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53796923], dtype=float32),
#   'logits': array([ 0.15216994], dtype=float32),
#   'probabilities': array([ 0.46203074,  0.53796923], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1507372], dtype=float32),
#   'logits': array([-1.72883081], dtype=float32),
#   'probabilities': array([ 0.84926283,  0.1507372 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53815746], dtype=float32),
#   'logits': array([ 0.15292716], dtype=float32),
#   'probabilities': array([ 0.46184254,  0.53815746], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14082541], dtype=float32),
#   'logits': array([-1.80845129], dtype=float32),
#   'probabilities': array([ 0.85917461,  0.14082541], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11113398], dtype=float32),
#   'logits': array([-2.07921004], dtype=float32),
#   'probabilities': array([ 0.88886601,  0.11113397], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59969765], dtype=float32),
#   'logits': array([ 0.40420544], dtype=float32),
#   'probabilities': array([ 0.40030238,  0.59969765], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18518932], dtype=float32),
#   'logits': array([-1.48157716], dtype=float32),
#   'probabilities': array([ 0.81481069,  0.18518932], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20210141], dtype=float32),
#   'logits': array([-1.37321186], dtype=float32),
#   'probabilities': array([ 0.79789859,  0.20210142], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11554465], dtype=float32),
#   'logits': array([-2.03531504], dtype=float32),
#   'probabilities': array([ 0.88445538,  0.11554465], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16953398], dtype=float32),
#   'logits': array([-1.58893359], dtype=float32),
#   'probabilities': array([ 0.83046603,  0.16953398], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2330627], dtype=float32),
#   'logits': array([-1.1910975], dtype=float32),
#   'probabilities': array([ 0.76693726,  0.2330627 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25487801], dtype=float32),
#   'logits': array([-1.07276285], dtype=float32),
#   'probabilities': array([ 0.74512202,  0.25487804], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38277897], dtype=float32),
#   'logits': array([-0.47776949], dtype=float32),
#   'probabilities': array([ 0.61722106,  0.38277897], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13208553], dtype=float32),
#   'logits': array([-1.88264346], dtype=float32),
#   'probabilities': array([ 0.8679145 ,  0.13208555], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21959187], dtype=float32),
#   'logits': array([-1.26804638], dtype=float32),
#   'probabilities': array([ 0.78040814,  0.21959187], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20533869], dtype=float32),
#   'logits': array([-1.35325527], dtype=float32),
#   'probabilities': array([ 0.79466134,  0.20533869], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2125037], dtype=float32),
#   'logits': array([-1.30989933], dtype=float32),
#   'probabilities': array([ 0.78749633,  0.21250369], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49170193], dtype=float32),
#   'logits': array([-0.0331955], dtype=float32),
#   'probabilities': array([ 0.5082981 ,  0.49170187], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16401695], dtype=float32),
#   'logits': array([-1.62863863], dtype=float32),
#   'probabilities': array([ 0.83598304,  0.16401695], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23305793], dtype=float32),
#   'logits': array([-1.1911242], dtype=float32),
#   'probabilities': array([ 0.76694202,  0.23305792], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6384545], dtype=float32),
#   'logits': array([ 0.56866264], dtype=float32),
#   'probabilities': array([ 0.36154547,  0.6384545 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61601657], dtype=float32),
#   'logits': array([ 0.47267437], dtype=float32),
#   'probabilities': array([ 0.38398346,  0.61601657], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50427997], dtype=float32),
#   'logits': array([ 0.01712024], dtype=float32),
#   'probabilities': array([ 0.49572   ,  0.50427991], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35525435], dtype=float32),
#   'logits': array([-0.59602183], dtype=float32),
#   'probabilities': array([ 0.64474565,  0.35525435], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4911114], dtype=float32),
#   'logits': array([-0.03555822], dtype=float32),
#   'probabilities': array([ 0.5088886 ,  0.49111137], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17050567], dtype=float32),
#   'logits': array([-1.5820477], dtype=float32),
#   'probabilities': array([ 0.8294943 ,  0.17050567], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19928961], dtype=float32),
#   'logits': array([-1.39074028], dtype=float32),
#   'probabilities': array([ 0.80071038,  0.19928961], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15360087], dtype=float32),
#   'logits': array([-1.70663357], dtype=float32),
#   'probabilities': array([ 0.84639919,  0.15360089], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1285665], dtype=float32),
#   'logits': array([-1.91369331], dtype=float32),
#   'probabilities': array([ 0.8714335,  0.1285665], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5950973], dtype=float32),
#   'logits': array([ 0.38507807], dtype=float32),
#   'probabilities': array([ 0.40490273,  0.5950973 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23373269], dtype=float32),
#   'logits': array([-1.18735301], dtype=float32),
#   'probabilities': array([ 0.7662673 ,  0.23373269], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44297963], dtype=float32),
#   'logits': array([-0.22907788], dtype=float32),
#   'probabilities': array([ 0.55702031,  0.44297966], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5828476], dtype=float32),
#   'logits': array([ 0.33447397], dtype=float32),
#   'probabilities': array([ 0.41715243,  0.5828476 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29740903], dtype=float32),
#   'logits': array([-0.85966659], dtype=float32),
#   'probabilities': array([ 0.702591,  0.297409], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.64738762], dtype=float32),
#   'logits': array([ 0.60757577], dtype=float32),
#   'probabilities': array([ 0.35261241,  0.64738762], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12694916], dtype=float32),
#   'logits': array([-1.92820716], dtype=float32),
#   'probabilities': array([ 0.87305087,  0.12694916], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61622047], dtype=float32),
#   'logits': array([ 0.47353637], dtype=float32),
#   'probabilities': array([ 0.38377959,  0.61622041], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11843038], dtype=float32),
#   'logits': array([-2.00737858], dtype=float32),
#   'probabilities': array([ 0.88156956,  0.11843038], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54918814], dtype=float32),
#   'logits': array([ 0.19739103], dtype=float32),
#   'probabilities': array([ 0.45081183,  0.54918814], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32984331], dtype=float32),
#   'logits': array([-0.70889384], dtype=float32),
#   'probabilities': array([ 0.67015672,  0.32984331], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1658581], dtype=float32),
#   'logits': array([-1.61527085], dtype=float32),
#   'probabilities': array([ 0.83414191,  0.1658581 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54337031], dtype=float32),
#   'logits': array([ 0.17391813], dtype=float32),
#   'probabilities': array([ 0.45662978,  0.54337031], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60227758], dtype=float32),
#   'logits': array([ 0.41496408], dtype=float32),
#   'probabilities': array([ 0.39772245,  0.60227758], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55653965], dtype=float32),
#   'logits': array([ 0.22713017], dtype=float32),
#   'probabilities': array([ 0.44346029,  0.55653965], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16706388], dtype=float32),
#   'logits': array([-1.60658073], dtype=float32),
#   'probabilities': array([ 0.83293611,  0.16706388], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36212519], dtype=float32),
#   'logits': array([-0.56615222], dtype=float32),
#   'probabilities': array([ 0.63787484,  0.36212513], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14068681], dtype=float32),
#   'logits': array([-1.80959725], dtype=float32),
#   'probabilities': array([ 0.85931313,  0.14068681], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.70918447], dtype=float32),
#   'logits': array([ 0.89142644], dtype=float32),
#   'probabilities': array([ 0.29081556,  0.70918447], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.80954719], dtype=float32),
#   'logits': array([ 1.44707048], dtype=float32),
#   'probabilities': array([ 0.19045283,  0.80954719], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61967742], dtype=float32),
#   'logits': array([ 0.48817933], dtype=float32),
#   'probabilities': array([ 0.38032258,  0.61967742], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21101613], dtype=float32),
#   'logits': array([-1.3188113], dtype=float32),
#   'probabilities': array([ 0.78898382,  0.21101612], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44213501], dtype=float32),
#   'logits': array([-0.23250175], dtype=float32),
#   'probabilities': array([ 0.55786496,  0.44213495], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38790426], dtype=float32),
#   'logits': array([-0.45613021], dtype=float32),
#   'probabilities': array([ 0.61209571,  0.38790423], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46696112], dtype=float32),
#   'logits': array([-0.13234842], dtype=float32),
#   'probabilities': array([ 0.53303891,  0.46696112], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34375975], dtype=float32),
#   'logits': array([-0.64658403], dtype=float32),
#   'probabilities': array([ 0.65624028,  0.34375975], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.45365503], dtype=float32),
#   'logits': array([-0.18591362], dtype=float32),
#   'probabilities': array([ 0.546345,  0.453655], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15658504], dtype=float32),
#   'logits': array([-1.68385983], dtype=float32),
#   'probabilities': array([ 0.84341496,  0.15658504], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54423511], dtype=float32),
#   'logits': array([ 0.17740428], dtype=float32),
#   'probabilities': array([ 0.45576486,  0.54423511], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53744525], dtype=float32),
#   'logits': array([ 0.15006196], dtype=float32),
#   'probabilities': array([ 0.46255475,  0.53744525], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23732413], dtype=float32),
#   'logits': array([-1.1674062], dtype=float32),
#   'probabilities': array([ 0.76267588,  0.23732416], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1789218], dtype=float32),
#   'logits': array([-1.52366948], dtype=float32),
#   'probabilities': array([ 0.82107824,  0.17892182], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17139105], dtype=float32),
#   'logits': array([-1.57580054], dtype=float32),
#   'probabilities': array([ 0.82860893,  0.17139104], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27660874], dtype=float32),
#   'logits': array([-0.96134621], dtype=float32),
#   'probabilities': array([ 0.72339129,  0.27660877], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39626655], dtype=float32),
#   'logits': array([-0.4210456], dtype=float32),
#   'probabilities': array([ 0.60373342,  0.39626655], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13717742], dtype=float32),
#   'logits': array([-1.83893394], dtype=float32),
#   'probabilities': array([ 0.86282259,  0.13717742], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33242005], dtype=float32),
#   'logits': array([-0.69725966], dtype=float32),
#   'probabilities': array([ 0.66757995,  0.33242008], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21656415], dtype=float32),
#   'logits': array([-1.28580236], dtype=float32),
#   'probabilities': array([ 0.78343582,  0.21656415], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.09096956], dtype=float32),
#   'logits': array([-2.30185366], dtype=float32),
#   'probabilities': array([ 0.90903038,  0.09096956], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11839826], dtype=float32),
#   'logits': array([-2.00768638], dtype=float32),
#   'probabilities': array([ 0.88160175,  0.11839827], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73703694], dtype=float32),
#   'logits': array([ 1.03062427], dtype=float32),
#   'probabilities': array([ 0.26296312,  0.73703694], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17940511], dtype=float32),
#   'logits': array([-1.52038324], dtype=float32),
#   'probabilities': array([ 0.82059491,  0.17940509], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13306738], dtype=float32),
#   'logits': array([-1.87410569], dtype=float32),
#   'probabilities': array([ 0.86693257,  0.13306737], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13509658], dtype=float32),
#   'logits': array([-1.85662782], dtype=float32),
#   'probabilities': array([ 0.86490339,  0.13509659], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49452531], dtype=float32),
#   'logits': array([-0.02189958], dtype=float32),
#   'probabilities': array([ 0.50547469,  0.49452534], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46439883], dtype=float32),
#   'logits': array([-0.14264607], dtype=float32),
#   'probabilities': array([ 0.53560114,  0.4643988 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23977596], dtype=float32),
#   'logits': array([-1.15390825], dtype=float32),
#   'probabilities': array([ 0.76022404,  0.23977594], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4476828], dtype=float32),
#   'logits': array([-0.21003753], dtype=float32),
#   'probabilities': array([ 0.5523172,  0.4476828], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.184416], dtype=float32),
#   'logits': array([-1.48671031], dtype=float32),
#   'probabilities': array([ 0.815584  ,  0.18441601], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2248898], dtype=float32),
#   'logits': array([-1.23739469], dtype=float32),
#   'probabilities': array([ 0.77511019,  0.2248898 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50426936], dtype=float32),
#   'logits': array([ 0.0170778], dtype=float32),
#   'probabilities': array([ 0.49573061,  0.5042693 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49336326], dtype=float32),
#   'logits': array([-0.0265485], dtype=float32),
#   'probabilities': array([ 0.50663674,  0.49336326], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13916509], dtype=float32),
#   'logits': array([-1.82224178], dtype=float32),
#   'probabilities': array([ 0.8608349,  0.1391651], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38930541], dtype=float32),
#   'logits': array([-0.4502328], dtype=float32),
#   'probabilities': array([ 0.61069459,  0.38930541], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67145383], dtype=float32),
#   'logits': array([ 0.71476793], dtype=float32),
#   'probabilities': array([ 0.32854614,  0.67145383], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54899168], dtype=float32),
#   'logits': array([ 0.19659734], dtype=float32),
#   'probabilities': array([ 0.45100838,  0.54899168], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40499312], dtype=float32),
#   'logits': array([-0.38470286], dtype=float32),
#   'probabilities': array([ 0.59500688,  0.40499315], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54964662], dtype=float32),
#   'logits': array([ 0.19924307], dtype=float32),
#   'probabilities': array([ 0.45035335,  0.54964662], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21425822], dtype=float32),
#   'logits': array([-1.29944634], dtype=float32),
#   'probabilities': array([ 0.78574181,  0.21425822], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19308519], dtype=float32),
#   'logits': array([-1.43008649], dtype=float32),
#   'probabilities': array([ 0.80691481,  0.19308521], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13371104], dtype=float32),
#   'logits': array([-1.86853743], dtype=float32),
#   'probabilities': array([ 0.86628896,  0.13371104], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24799748], dtype=float32),
#   'logits': array([-1.10932112], dtype=float32),
#   'probabilities': array([ 0.75200254,  0.24799749], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.47916499], dtype=float32),
#   'logits': array([-0.08338845], dtype=float32),
#   'probabilities': array([ 0.52083504,  0.47916496], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67122352], dtype=float32),
#   'logits': array([ 0.71372402], dtype=float32),
#   'probabilities': array([ 0.32877651,  0.67122352], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21598133], dtype=float32),
#   'logits': array([-1.28924084], dtype=float32),
#   'probabilities': array([ 0.7840187 ,  0.21598133], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15174522], dtype=float32),
#   'logits': array([-1.72097814], dtype=float32),
#   'probabilities': array([ 0.8482548 ,  0.15174522], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42234734], dtype=float32),
#   'logits': array([-0.31314468], dtype=float32),
#   'probabilities': array([ 0.57765263,  0.42234734], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23035182], dtype=float32),
#   'logits': array([-1.20632577], dtype=float32),
#   'probabilities': array([ 0.76964819,  0.23035182], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14610627], dtype=float32),
#   'logits': array([-1.76547253], dtype=float32),
#   'probabilities': array([ 0.85389376,  0.14610627], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18378794], dtype=float32),
#   'logits': array([-1.49089158], dtype=float32),
#   'probabilities': array([ 0.81621206,  0.18378794], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11904936], dtype=float32),
#   'logits': array([-2.00146341], dtype=float32),
#   'probabilities': array([ 0.88095069,  0.11904937], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39179334], dtype=float32),
#   'logits': array([-0.43978018], dtype=float32),
#   'probabilities': array([ 0.60820663,  0.39179334], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.76332104], dtype=float32),
#   'logits': array([ 1.1709739], dtype=float32),
#   'probabilities': array([ 0.236679  ,  0.76332104], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.75780517], dtype=float32),
#   'logits': array([ 1.14068401], dtype=float32),
#   'probabilities': array([ 0.24219479,  0.75780517], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54312652], dtype=float32),
#   'logits': array([ 0.17293596], dtype=float32),
#   'probabilities': array([ 0.45687339,  0.54312652], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49322772], dtype=float32),
#   'logits': array([-0.02709091], dtype=float32),
#   'probabilities': array([ 0.50677228,  0.49322763], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54983693], dtype=float32),
#   'logits': array([ 0.20001185], dtype=float32),
#   'probabilities': array([ 0.45016307,  0.54983693], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11459784], dtype=float32),
#   'logits': array([-2.04461288], dtype=float32),
#   'probabilities': array([ 0.88540214,  0.11459785], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52394545], dtype=float32),
#   'logits': array([ 0.09585512], dtype=float32),
#   'probabilities': array([ 0.47605455,  0.52394545], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.75672477], dtype=float32),
#   'logits': array([ 1.13480604], dtype=float32),
#   'probabilities': array([ 0.24327527,  0.75672477], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3991946], dtype=float32),
#   'logits': array([-0.40882224], dtype=float32),
#   'probabilities': array([ 0.60080546,  0.39919457], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26514307], dtype=float32),
#   'logits': array([-1.01940632], dtype=float32),
#   'probabilities': array([ 0.73485696,  0.26514307], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35766274], dtype=float32),
#   'logits': array([-0.58552307], dtype=float32),
#   'probabilities': array([ 0.64233726,  0.35766274], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.58974421], dtype=float32),
#   'logits': array([ 0.36290801], dtype=float32),
#   'probabilities': array([ 0.41025582,  0.58974421], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23747614], dtype=float32),
#   'logits': array([-1.16656661], dtype=float32),
#   'probabilities': array([ 0.76252383,  0.23747614], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65257293], dtype=float32),
#   'logits': array([ 0.63036788], dtype=float32),
#   'probabilities': array([ 0.34742716,  0.65257293], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40641204], dtype=float32),
#   'logits': array([-0.37881792], dtype=float32),
#   'probabilities': array([ 0.59358799,  0.40641207], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40712941], dtype=float32),
#   'logits': array([-0.37584507], dtype=float32),
#   'probabilities': array([ 0.59287059,  0.40712938], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16081178], dtype=float32),
#   'logits': array([-1.65220046], dtype=float32),
#   'probabilities': array([ 0.83918828,  0.16081178], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18798882], dtype=float32),
#   'logits': array([-1.46313155], dtype=float32),
#   'probabilities': array([ 0.81201118,  0.18798883], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1728933], dtype=float32),
#   'logits': array([-1.5652591], dtype=float32),
#   'probabilities': array([ 0.82710671,  0.1728933 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44039482], dtype=float32),
#   'logits': array([-0.23955989], dtype=float32),
#   'probabilities': array([ 0.55960518,  0.44039479], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14957842], dtype=float32),
#   'logits': array([-1.73791134], dtype=float32),
#   'probabilities': array([ 0.85042161,  0.14957844], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73661107], dtype=float32),
#   'logits': array([ 1.02842844], dtype=float32),
#   'probabilities': array([ 0.26338887,  0.73661107], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20039006], dtype=float32),
#   'logits': array([-1.38385832], dtype=float32),
#   'probabilities': array([ 0.79960996,  0.20039006], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51072037], dtype=float32),
#   'logits': array([ 0.04288816], dtype=float32),
#   'probabilities': array([ 0.4892796 ,  0.51072037], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15529364], dtype=float32),
#   'logits': array([-1.69367123], dtype=float32),
#   'probabilities': array([ 0.84470636,  0.15529364], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65618461], dtype=float32),
#   'logits': array([ 0.64633727], dtype=float32),
#   'probabilities': array([ 0.34381542,  0.65618461], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32063073], dtype=float32),
#   'logits': array([-0.75087476], dtype=float32),
#   'probabilities': array([ 0.67936927,  0.3206307 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19506907], dtype=float32),
#   'logits': array([-1.41740274], dtype=float32),
#   'probabilities': array([ 0.80493093,  0.19506907], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35154986], dtype=float32),
#   'logits': array([-0.61223364], dtype=float32),
#   'probabilities': array([ 0.64845014,  0.35154983], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.31059268], dtype=float32),
#   'logits': array([-0.79734981], dtype=float32),
#   'probabilities': array([ 0.68940729,  0.31059271], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16719574], dtype=float32),
#   'logits': array([-1.6056335], dtype=float32),
#   'probabilities': array([ 0.83280432,  0.16719574], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.70180994], dtype=float32),
#   'logits': array([ 0.85593164], dtype=float32),
#   'probabilities': array([ 0.29819006,  0.70180994], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18799618], dtype=float32),
#   'logits': array([-1.46308339], dtype=float32),
#   'probabilities': array([ 0.81200379,  0.18799618], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17137682], dtype=float32),
#   'logits': array([-1.57590079], dtype=float32),
#   'probabilities': array([ 0.82862318,  0.17137682], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26303661], dtype=float32),
#   'logits': array([-1.03024507], dtype=float32),
#   'probabilities': array([ 0.73696339,  0.26303658], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.45334917], dtype=float32),
#   'logits': array([-0.18714774], dtype=float32),
#   'probabilities': array([ 0.54665089,  0.45334917], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27084294], dtype=float32),
#   'logits': array([-0.99035001], dtype=float32),
#   'probabilities': array([ 0.72915709,  0.27084297], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11304717], dtype=float32),
#   'logits': array([-2.05998659], dtype=float32),
#   'probabilities': array([ 0.88695282,  0.11304718], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.83895558], dtype=float32),
#   'logits': array([ 1.65047801], dtype=float32),
#   'probabilities': array([ 0.16104434,  0.83895558], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.66796911], dtype=float32),
#   'logits': array([ 0.69901395], dtype=float32),
#   'probabilities': array([ 0.33203089,  0.66796911], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52016705], dtype=float32),
#   'logits': array([ 0.08071196], dtype=float32),
#   'probabilities': array([ 0.47983298,  0.52016705], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.70382917], dtype=float32),
#   'logits': array([ 0.86559951], dtype=float32),
#   'probabilities': array([ 0.29617074,  0.70382917], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11100251], dtype=float32),
#   'logits': array([-2.08054161], dtype=float32),
#   'probabilities': array([ 0.8889975 ,  0.11100251], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14478204], dtype=float32),
#   'logits': array([-1.77612698], dtype=float32),
#   'probabilities': array([ 0.85521793,  0.14478202], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20046529], dtype=float32),
#   'logits': array([-1.38338888], dtype=float32),
#   'probabilities': array([ 0.79953474,  0.20046528], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33281577], dtype=float32),
#   'logits': array([-0.69547713], dtype=float32),
#   'probabilities': array([ 0.66718423,  0.33281577], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36940178], dtype=float32),
#   'logits': array([-0.5347839], dtype=float32),
#   'probabilities': array([ 0.63059819,  0.36940181], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55928504], dtype=float32),
#   'logits': array([ 0.23826087], dtype=float32),
#   'probabilities': array([ 0.44071501,  0.55928504], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
# ...
#   'logits': array([ 0.18090594], dtype=float32),
#   'probabilities': array([ 0.45489645,  0.54510355], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37706339], dtype=float32),
#   'logits': array([-0.50203145], dtype=float32),
#   'probabilities': array([ 0.62293661,  0.37706339], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37310293], dtype=float32),
#   'logits': array([-0.51892811], dtype=float32),
#   'probabilities': array([ 0.6268971 ,  0.37310293], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3562746], dtype=float32),
#   'logits': array([-0.5915705], dtype=float32),
#   'probabilities': array([ 0.6437254 ,  0.35627457], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18881796], dtype=float32),
#   'logits': array([-1.45770907], dtype=float32),
#   'probabilities': array([ 0.81118202,  0.18881796], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62928158], dtype=float32),
#   'logits': array([ 0.52913618], dtype=float32),
#   'probabilities': array([ 0.37071836,  0.62928158], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12316995], dtype=float32),
#   'logits': array([-1.96274805], dtype=float32),
#   'probabilities': array([ 0.8768301 ,  0.12316996], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25673053], dtype=float32),
#   'logits': array([-1.06303167], dtype=float32),
#   'probabilities': array([ 0.7432695 ,  0.25673053], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52448457], dtype=float32),
#   'logits': array([ 0.0980165], dtype=float32),
#   'probabilities': array([ 0.47551548,  0.52448452], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35377872], dtype=float32),
#   'logits': array([-0.60247034], dtype=float32),
#   'probabilities': array([ 0.64622128,  0.35377875], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1911926], dtype=float32),
#   'logits': array([-1.44227958], dtype=float32),
#   'probabilities': array([ 0.80880737,  0.19119258], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27353945], dtype=float32),
#   'logits': array([-0.97673833], dtype=float32),
#   'probabilities': array([ 0.72646058,  0.27353945], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25472671], dtype=float32),
#   'logits': array([-1.07355976], dtype=float32),
#   'probabilities': array([ 0.74527323,  0.25472668], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12988324], dtype=float32),
#   'logits': array([-1.90199149], dtype=float32),
#   'probabilities': array([ 0.87011677,  0.12988324], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18257757], dtype=float32),
#   'logits': array([-1.498981], dtype=float32),
#   'probabilities': array([ 0.81742245,  0.18257755], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55185819], dtype=float32),
#   'logits': array([ 0.20818138], dtype=float32),
#   'probabilities': array([ 0.44814181,  0.55185819], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.69743532], dtype=float32),
#   'logits': array([ 0.83511496], dtype=float32),
#   'probabilities': array([ 0.30256462,  0.69743538], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61222637], dtype=float32),
#   'logits': array([ 0.4566803], dtype=float32),
#   'probabilities': array([ 0.38777366,  0.61222637], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.68993151], dtype=float32),
#   'logits': array([ 0.79979897], dtype=float32),
#   'probabilities': array([ 0.31006855,  0.68993151], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4548699], dtype=float32),
#   'logits': array([-0.18101299], dtype=float32),
#   'probabilities': array([ 0.54513007,  0.4548699 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29261339], dtype=float32),
#   'logits': array([-0.88272518], dtype=float32),
#   'probabilities': array([ 0.70738661,  0.29261336], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50829452], dtype=float32),
#   'logits': array([ 0.03318107], dtype=float32),
#   'probabilities': array([ 0.49170551,  0.50829452], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18117771], dtype=float32),
#   'logits': array([-1.50838876], dtype=float32),
#   'probabilities': array([ 0.81882226,  0.18117771], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14066629], dtype=float32),
#   'logits': array([-1.80976701], dtype=float32),
#   'probabilities': array([ 0.85933375,  0.14066629], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18089341], dtype=float32),
#   'logits': array([-1.51030636], dtype=float32),
#   'probabilities': array([ 0.81910658,  0.18089338], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51126379], dtype=float32),
#   'logits': array([ 0.04506278], dtype=float32),
#   'probabilities': array([ 0.48873621,  0.51126379], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.06148246], dtype=float32),
#   'logits': array([-2.7255497], dtype=float32),
#   'probabilities': array([ 0.93851757,  0.06148246], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27910182], dtype=float32),
#   'logits': array([-0.94892132], dtype=float32),
#   'probabilities': array([ 0.72089821,  0.27910182], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16605908], dtype=float32),
#   'logits': array([-1.61381888], dtype=float32),
#   'probabilities': array([ 0.83394086,  0.16605908], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27736464], dtype=float32),
#   'logits': array([-0.95757169], dtype=float32),
#   'probabilities': array([ 0.72263533,  0.27736464], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2414093], dtype=float32),
#   'logits': array([-1.14496851], dtype=float32),
#   'probabilities': array([ 0.7585907,  0.2414093], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26319581], dtype=float32),
#   'logits': array([-1.02942395], dtype=float32),
#   'probabilities': array([ 0.73680419,  0.26319578], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.76325572], dtype=float32),
#   'logits': array([ 1.17061269], dtype=float32),
#   'probabilities': array([ 0.23674425,  0.76325572], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17594951], dtype=float32),
#   'logits': array([-1.54403472], dtype=float32),
#   'probabilities': array([ 0.82405049,  0.17594951], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12499732], dtype=float32),
#   'logits': array([-1.94593465], dtype=float32),
#   'probabilities': array([ 0.87500268,  0.12499733], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59244215], dtype=float32),
#   'logits': array([ 0.37407029], dtype=float32),
#   'probabilities': array([ 0.40755787,  0.59244215], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48142853], dtype=float32),
#   'logits': array([-0.07432008], dtype=float32),
#   'probabilities': array([ 0.51857144,  0.48142847], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.84573066], dtype=float32),
#   'logits': array([ 1.70150101], dtype=float32),
#   'probabilities': array([ 0.15426932,  0.84573066], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6497333], dtype=float32),
#   'logits': array([ 0.61786711], dtype=float32),
#   'probabilities': array([ 0.3502667,  0.6497333], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12560937], dtype=float32),
#   'logits': array([-1.94035029], dtype=float32),
#   'probabilities': array([ 0.8743906 ,  0.12560937], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.63846278], dtype=float32),
#   'logits': array([ 0.56869841], dtype=float32),
#   'probabilities': array([ 0.36153722,  0.63846278], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53570253], dtype=float32),
#   'logits': array([ 0.14305353], dtype=float32),
#   'probabilities': array([ 0.4642975 ,  0.53570253], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.76407653], dtype=float32),
#   'logits': array([ 1.17516029], dtype=float32),
#   'probabilities': array([ 0.23592353,  0.76407653], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21878214], dtype=float32),
#   'logits': array([-1.27277756], dtype=float32),
#   'probabilities': array([ 0.78121787,  0.21878214], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16210197], dtype=float32),
#   'logits': array([-1.64267087], dtype=float32),
#   'probabilities': array([ 0.83789808,  0.16210197], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53594875], dtype=float32),
#   'logits': array([ 0.14404345], dtype=float32),
#   'probabilities': array([ 0.46405125,  0.53594869], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15083687], dtype=float32),
#   'logits': array([-1.72805238], dtype=float32),
#   'probabilities': array([ 0.84916312,  0.15083687], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.76067799], dtype=float32),
#   'logits': array([ 1.15640032], dtype=float32),
#   'probabilities': array([ 0.23932199,  0.76067799], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5266434], dtype=float32),
#   'logits': array([ 0.10667455], dtype=float32),
#   'probabilities': array([ 0.47335663,  0.5266434 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17290597], dtype=float32),
#   'logits': array([-1.56517053], dtype=float32),
#   'probabilities': array([ 0.82709408,  0.17290597], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55775875], dtype=float32),
#   'logits': array([ 0.23207092], dtype=float32),
#   'probabilities': array([ 0.44224128,  0.55775875], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46285698], dtype=float32),
#   'logits': array([-0.14884627], dtype=float32),
#   'probabilities': array([ 0.53714299,  0.46285698], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11161546], dtype=float32),
#   'logits': array([-2.07434511], dtype=float32),
#   'probabilities': array([ 0.88838452,  0.11161546], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5081346], dtype=float32),
#   'logits': array([ 0.03254128], dtype=float32),
#   'probabilities': array([ 0.4918654,  0.5081346], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57091409], dtype=float32),
#   'logits': array([ 0.28558159], dtype=float32),
#   'probabilities': array([ 0.42908591,  0.57091409], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.7280882], dtype=float32),
#   'logits': array([ 0.98494446], dtype=float32),
#   'probabilities': array([ 0.2719118,  0.7280882], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.79931319], dtype=float32),
#   'logits': array([ 1.382007], dtype=float32),
#   'probabilities': array([ 0.20068687,  0.79931319], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44011021], dtype=float32),
#   'logits': array([-0.24071479], dtype=float32),
#   'probabilities': array([ 0.55988979,  0.44011024], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15940775], dtype=float32),
#   'logits': array([-1.66264129], dtype=float32),
#   'probabilities': array([ 0.84059227,  0.15940775], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.08541906], dtype=float32),
#   'logits': array([-2.37089682], dtype=float32),
#   'probabilities': array([ 0.91458094,  0.08541905], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10871375], dtype=float32),
#   'logits': array([-2.1039474], dtype=float32),
#   'probabilities': array([ 0.89128625,  0.10871375], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25883868], dtype=float32),
#   'logits': array([-1.05201316], dtype=float32),
#   'probabilities': array([ 0.74116129,  0.25883871], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30962008], dtype=float32),
#   'logits': array([-0.8018961], dtype=float32),
#   'probabilities': array([ 0.69037998,  0.30962008], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27223521], dtype=float32),
#   'logits': array([-0.98331141], dtype=float32),
#   'probabilities': array([ 0.72776473,  0.27223521], dtype=float32)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\shaha\AppData\Local\Temp\tmpz82z4tcr
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\shaha\\AppData\\Local\\Temp\\tmpz82z4tcr', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001499C0A07F0>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\shaha\AppData\Local\Temp\tmpnkyisw64
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\shaha\\AppData\\Local\\Temp\\tmpnkyisw64', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001492AA8AC88>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\shaha\AppData\Local\Temp\tmpnkyisw64\model.ckpt.
# INFO:tensorflow:loss = 7.33388, step = 1
# INFO:tensorflow:global_step/sec: 98.1117
# INFO:tensorflow:loss = 7.34451, step = 101 (1.022 sec)
# INFO:tensorflow:global_step/sec: 108.623
# INFO:tensorflow:loss = 4.44176, step = 201 (0.922 sec)
# INFO:tensorflow:global_step/sec: 102.723
# INFO:tensorflow:loss = 5.21167, step = 301 (0.971 sec)
# INFO:tensorflow:global_step/sec: 111.302
# INFO:tensorflow:loss = 5.23106, step = 401 (0.898 sec)
# INFO:tensorflow:global_step/sec: 105.296
# INFO:tensorflow:loss = 9.37247, step = 501 (0.950 sec)
# INFO:tensorflow:global_step/sec: 97.1513
# INFO:tensorflow:loss = 7.03403, step = 601 (1.029 sec)
# INFO:tensorflow:global_step/sec: 106.04
# INFO:tensorflow:loss = 4.18324, step = 701 (0.943 sec)
# INFO:tensorflow:global_step/sec: 106.063
# INFO:tensorflow:loss = 6.86958, step = 801 (0.943 sec)
# INFO:tensorflow:global_step/sec: 92.3001
# INFO:tensorflow:loss = 5.46238, step = 901 (1.086 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\shaha\AppData\Local\Temp\tmpnkyisw64\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.64318.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-27-15:11:58
# INFO:tensorflow:Restoring parameters from C:\Users\shaha\AppData\Local\Temp\tmpnkyisw64\model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-11-27-15:12:00
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.720472, accuracy_baseline = 0.65748, auc = 0.80508, auc_precision_recall = 0.659153, average_loss = 0.506774, global_step = 1000, label/mean = 0.34252, loss = 4.9508, prediction/mean = 0.346123
# {'accuracy': 0.72047246,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.80507952,
#  'auc_precision_recall': 0.65915334,
#  'average_loss': 0.50677431,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 4.9507952,
#  'prediction/mean': 0.34612301}
